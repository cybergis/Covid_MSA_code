# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cases = pd.read_csv('./data/output.csv')
test_list = []
test_list_date = []
for index, row in cases.iterrows():
    if (row['name_msa'] == 'New York-Newark-Jersey City'):
        test_list.append(row['cases'])
        test_list_date.append(row['interval_start'])

# %%
plt.plot(test_list_date, test_list)
plt.title('Covid-19 cases at New York-Newark-Jersey City area, 2/14/2020 - 6/11/2020')
# Out:
# Text(0.5, 1.0, 'Covid-19 cases at New York-Newark-Jersey City area, 2/14/2020 - 6/11/2020')

# %%
travels = pd.read_csv('./MSA_travel_aggregate_code/output.csv')
for index, row in travels.iterrows():
    if (row['name_msa'] == 'New York-Newark-Jersey City'):
        test_list_travels =  list(row)
        test_list_travels.pop(0)
        dates = list(travels)
        dates.pop(0)
        plt.plot(dates, test_list_travels)
        plt.title('travelers to New York-Newark-Jersey City area, 2/14/2020 - 6/11/2020')
        break
